# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar([0, 1, 2, 3], [1, 2, 3, 4], align='center', tick_label=['a', 'b', 'c', 'd'])
plt.show()

# %%
plt.figure()
plt.bar([0, 1, 2, 3], [0.982666015625, 0.0166015625, 0.00048828125, 0.000244140625], align='center', tick_label=['00', '10', '01', '11'])
plt.show()

# %%
plt.figure()
plt.bar([0, 1, 2, 3], [0.4566650390625, 0.4227294921875, 0.0618896484375, 0.0587158203125], align='center', tick_label=['00', '10', '11', '01'])
plt.show()

# %%
import numpy as np

# %%
arr = np.array([[3, 0], [0, 5]])
np.linalg.pinv(arr)
# Out:
# array([[0.33333333, 0.        ],
#        [0.        , 0.2       ]])
