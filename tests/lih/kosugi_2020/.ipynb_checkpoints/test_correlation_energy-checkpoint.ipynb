# %%
import sys
sys.path.append('../../../src/')
from greens_function import *
from ansatze import *
from hamiltonians import *
from constants import *
# Out:
# /home/snsunx/anaconda3/envs/qiskit/lib/python3.8/site-packages/qiskit/aqua/__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')
# /home/snsunx/.local/lib/python3.8/site-packages/pyscf/lib/misc.py:46: H5pyDeprecationWarning: Using default_file_mode other than 'r' is deprecated. Pass the mode to h5py.File() instead.
#   h5py.get_config().default_file_mode = 'a'

# %%
ansatz = build_kosugi_lih_ansatz(1)
hamiltonian = MolecularHamiltonian(
    [['Li', (0, 0, 0)], ['H', (0, 0, 1.6)]], 'sto3g')
greens_function = GreensFunction(ansatz, hamiltonian)
greens_function.compute_ground_state()
greens_function.compute_eh_states()
greens_function.compute_diagonal_amplitudes()
greens_function.compute_off_diagonal_amplitudes()

E1, E2 = greens_function.compute_correlation_energy()
# Out:
# Ground state energy = -214.332 eV
# Calculations of (N+/-1)-electron states finished.
# m = 0
# Statevector simulator mode.
# m = 1
# Statevector simulator mode.
# m = 2
# Statevector simulator mode.
# m = 3
# Statevector simulator mode.
# m = 4
# Statevector simulator mode.
# m = 5
# Statevector simulator mode.
# m = 6
# Statevector simulator mode.
# m = 7
# Statevector simulator mode.
# m = 8
# Statevector simulator mode.
# m = 9
# Statevector simulator mode.
# m = 10
# Statevector simulator mode.
# m = 11
# Statevector simulator mode.
# Calculations of diagonal transition amplitudes finished.
# (m, n) = (0, 1)
# Statevector simulator mode.
# (m, n) = (0, 2)
# Statevector simulator mode.
# (m, n) = (0, 3)
# Statevector simulator mode.
# (m, n) = (0, 4)
# Statevector simulator mode.
# (m, n) = (0, 5)
# Statevector simulator mode.
# (m, n) = (0, 6)
# Statevector simulator mode.
# (m, n) = (0, 7)
# Statevector simulator mode.
# (m, n) = (0, 8)
# Statevector simulator mode.
# (m, n) = (0, 9)
# Statevector simulator mode.
# (m, n) = (0, 10)
# Statevector simulator mode.
# (m, n) = (0, 11)
# Statevector simulator mode.
# (m, n) = (1, 0)
# Statevector simulator mode.
# (m, n) = (1, 2)
# Statevector simulator mode.
# (m, n) = (1, 3)
# Statevector simulator mode.
# (m, n) = (1, 4)
# Statevector simulator mode.
# (m, n) = (1, 5)
# Statevector simulator mode.
# (m, n) = (1, 6)
# Statevector simulator mode.
# (m, n) = (1, 7)
# Statevector simulator mode.
# (m, n) = (1, 8)
# Statevector simulator mode.
# (m, n) = (1, 9)
# Statevector simulator mode.
# (m, n) = (1, 10)
# Statevector simulator mode.
# (m, n) = (1, 11)
# Statevector simulator mode.
# (m, n) = (2, 0)
# Statevector simulator mode.
# (m, n) = (2, 1)
# Statevector simulator mode.
# (m, n) = (2, 3)
# Statevector simulator mode.
# (m, n) = (2, 4)
# Statevector simulator mode.
# (m, n) = (2, 5)
# Statevector simulator mode.
# (m, n) = (2, 6)
# Statevector simulator mode.
# (m, n) = (2, 7)
# Statevector simulator mode.
# (m, n) = (2, 8)
# Statevector simulator mode.
# (m, n) = (2, 9)
# Statevector simulator mode.
# (m, n) = (2, 10)
# Statevector simulator mode.
# (m, n) = (2, 11)
# Statevector simulator mode.
# (m, n) = (3, 0)
# Statevector simulator mode.
# (m, n) = (3, 1)
# Statevector simulator mode.
# (m, n) = (3, 2)
# Statevector simulator mode.
# (m, n) = (3, 4)
# Statevector simulator mode.
# (m, n) = (3, 5)
# Statevector simulator mode.
# (m, n) = (3, 6)
# Statevector simulator mode.
# (m, n) = (3, 7)
# Statevector simulator mode.
# (m, n) = (3, 8)
# Statevector simulator mode.
# (m, n) = (3, 9)
# Statevector simulator mode.
# (m, n) = (3, 10)
# Statevector simulator mode.
# (m, n) = (3, 11)
# Statevector simulator mode.
# (m, n) = (4, 0)
# Statevector simulator mode.
# (m, n) = (4, 1)
# Statevector simulator mode.
# (m, n) = (4, 2)
# Statevector simulator mode.
# (m, n) = (4, 3)
# Statevector simulator mode.
# (m, n) = (4, 5)
# Statevector simulator mode.
# (m, n) = (4, 6)
# Statevector simulator mode.
# (m, n) = (4, 7)
# Statevector simulator mode.
# (m, n) = (4, 8)
# Statevector simulator mode.
# (m, n) = (4, 9)
# Statevector simulator mode.
# (m, n) = (4, 10)
# Statevector simulator mode.
# (m, n) = (4, 11)
# Statevector simulator mode.
# (m, n) = (5, 0)
# Statevector simulator mode.
# (m, n) = (5, 1)
# Statevector simulator mode.
# (m, n) = (5, 2)
# Statevector simulator mode.
# (m, n) = (5, 3)
# Statevector simulator mode.
# (m, n) = (5, 4)
# Statevector simulator mode.
# (m, n) = (5, 6)
# Statevector simulator mode.
# (m, n) = (5, 7)
# Statevector simulator mode.
# (m, n) = (5, 8)
# Statevector simulator mode.
# (m, n) = (5, 9)
# Statevector simulator mode.
# (m, n) = (5, 10)
# Statevector simulator mode.
# (m, n) = (5, 11)
# Statevector simulator mode.
# (m, n) = (6, 0)
# Statevector simulator mode.
# (m, n) = (6, 1)
# Statevector simulator mode.
# (m, n) = (6, 2)
# Statevector simulator mode.
# (m, n) = (6, 3)
# Statevector simulator mode.
# (m, n) = (6, 4)
# Statevector simulator mode.
# (m, n) = (6, 5)
# Statevector simulator mode.
# (m, n) = (6, 7)
# Statevector simulator mode.
# (m, n) = (6, 8)
# Statevector simulator mode.
# (m, n) = (6, 9)
# Statevector simulator mode.
# (m, n) = (6, 10)
# Statevector simulator mode.
# (m, n) = (6, 11)
# Statevector simulator mode.
# (m, n) = (7, 0)
# Statevector simulator mode.
# (m, n) = (7, 1)
# Statevector simulator mode.
# (m, n) = (7, 2)
# Statevector simulator mode.
# (m, n) = (7, 3)
# Statevector simulator mode.
# (m, n) = (7, 4)
# Statevector simulator mode.
# (m, n) = (7, 5)
# Statevector simulator mode.
# (m, n) = (7, 6)
# Statevector simulator mode.
# (m, n) = (7, 8)
# Statevector simulator mode.
# (m, n) = (7, 9)
# Statevector simulator mode.
# (m, n) = (7, 10)
# Statevector simulator mode.
# (m, n) = (7, 11)
# Statevector simulator mode.
# (m, n) = (8, 0)
# Statevector simulator mode.
# (m, n) = (8, 1)
# Statevector simulator mode.
# (m, n) = (8, 2)
# Statevector simulator mode.
# (m, n) = (8, 3)
# Statevector simulator mode.
# (m, n) = (8, 4)
# Statevector simulator mode.
# (m, n) = (8, 5)
# Statevector simulator mode.
# (m, n) = (8, 6)
# Statevector simulator mode.
# (m, n) = (8, 7)
# Statevector simulator mode.
# (m, n) = (8, 9)
# Statevector simulator mode.
# (m, n) = (8, 10)
# Statevector simulator mode.
# (m, n) = (8, 11)
# Statevector simulator mode.
# (m, n) = (9, 0)
# Statevector simulator mode.
# (m, n) = (9, 1)
# Statevector simulator mode.
# (m, n) = (9, 2)
# Statevector simulator mode.
# (m, n) = (9, 3)
# Statevector simulator mode.
# (m, n) = (9, 4)
# Statevector simulator mode.
# (m, n) = (9, 5)
# Statevector simulator mode.
# (m, n) = (9, 6)
# Statevector simulator mode.
# (m, n) = (9, 7)
# Statevector simulator mode.
# (m, n) = (9, 8)
# Statevector simulator mode.
# (m, n) = (9, 10)
# Statevector simulator mode.
# (m, n) = (9, 11)
# Statevector simulator mode.
# (m, n) = (10, 0)
# Statevector simulator mode.
# (m, n) = (10, 1)
# Statevector simulator mode.
# (m, n) = (10, 2)
# Statevector simulator mode.
# (m, n) = (10, 3)
# Statevector simulator mode.
# (m, n) = (10, 4)
# Statevector simulator mode.
# (m, n) = (10, 5)
# Statevector simulator mode.
# (m, n) = (10, 6)
# Statevector simulator mode.
# (m, n) = (10, 7)
# Statevector simulator mode.
# (m, n) = (10, 8)
# Statevector simulator mode.
# (m, n) = (10, 9)
# Statevector simulator mode.
# (m, n) = (10, 11)
# Statevector simulator mode.
# (m, n) = (11, 0)
# Statevector simulator mode.
# (m, n) = (11, 1)
# Statevector simulator mode.
# (m, n) = (11, 2)
# Statevector simulator mode.
# (m, n) = (11, 3)
# Statevector simulator mode.
# (m, n) = (11, 4)
# Statevector simulator mode.
# (m, n) = (11, 5)
# Statevector simulator mode.
# (m, n) = (11, 6)
# Statevector simulator mode.
# (m, n) = (11, 7)
# Statevector simulator mode.
# (m, n) = (11, 8)
# Statevector simulator mode.
# (m, n) = (11, 9)
# Statevector simulator mode.
# (m, n) = (11, 10)
# Statevector simulator mode.
# Calculations of off-diagonal transition amplitudes finished.
# i = 0
# /mnt/c/Users/snsun/Documents/Code/Github/greens-function/tests/lih/kosugi_2020/../../../src/greens_function.py:415: RuntimeWarning: invalid value encountered in true_divide
#   self.B_h[m, n] / (omega - self.energy_gs + self.energies_h))
# /mnt/c/Users/snsun/Documents/Code/Github/greens-function/tests/lih/kosugi_2020/../../../src/greens_function.py:415: RuntimeWarning: divide by zero encountered in true_divide
#   self.B_h[m, n] / (omega - self.energy_gs + self.energies_h))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_2111/3397423962.py in <module>
#       8 greens_function.compute_off_diagonal_amplitudes()
#       9
# ---> 10 E1, E2 = greens_function.compute_correlation_energy()
#
# /mnt/c/Users/snsun/Documents/Code/Github/greens-function/tests/lih/kosugi_2020/../../../src/greens_function.py in compute_correlation_energy(self)
#     447             print('i =', i)
#     448             e_qp = - (self.energies_h[i] - self.energy_gs)
# --> 449             Sigma = self.compute_self_energy(e_qp)
#     450             E2 += np.trace(Sigma @ self.B_h[:,:,i]) / 2
#     451         return E1, E2
#
# /mnt/c/Users/snsun/Documents/Code/Github/greens-function/tests/lih/kosugi_2020/../../../src/greens_function.py in compute_self_energy(self, omega)
#     434             G_HF[i, i] = 1 / (omega - self.molecule.orbital_energies[i // 2] * HARTREE_TO_EV)
#     435
# --> 436         Sigma = np.linalg.pinv(G_HF) - np.linalg.pinv(self.G)
#     437         return Sigma
#     438
#
# <__array_function__ internals> in pinv(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py in pinv(a, rcond, hermitian)
#    2000         return wrap(res)
#    2001     a = a.conjugate()
# -> 2002     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2003
#    2004     # discard small singular values
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1658
#    1659         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1660         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1661         u = u.astype(result_t, copy=False)
#    1662         s = s.astype(_realType(result_t), copy=False)
#
# ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#      95
#      96 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 97     raise LinAlgError("SVD did not converge")
#      98
#      99 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge

# %%
for i in range(10):
    greens_function.compute_self_energy(-7.14054356)
# Out:
# array([[ 6.15910974e+01-1.95524236e-15j,  2.77713802e-08-1.06997395e-10j,
#         -1.27930013e-03+2.99957403e-09j, -8.86389832e-10+5.17899966e-09j,
#          9.93475575e-05-2.40903478e-09j,  1.96491214e-09-4.53287789e-09j,
#         -6.08258348e-12+4.97085020e-10j, -6.08278564e-12+4.97084841e-10j,
#         -6.08278396e-12+4.97084842e-10j, -6.08258479e-12+4.97085018e-10j,
#         -1.45599590e-03+1.07381703e-07j, -3.13895206e-08+1.85376187e-07j],
#        [ 1.65554538e-10+1.06996283e-10j,  6.15916054e+01+6.38378239e-16j,
#         -4.45360302e-10+3.61138832e-09j, -1.27944956e-03+2.95144948e-09j,
#          1.90951164e-10-3.06911732e-09j,  9.93613314e-05-2.39069100e-09j,
#          1.78119802e-12+4.97147167e-10j,  1.78099596e-12+4.97147382e-10j,
#          1.78098869e-12+4.97147374e-10j,  1.78099817e-12+4.97147362e-10j,
